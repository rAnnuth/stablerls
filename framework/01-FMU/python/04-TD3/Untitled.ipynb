# %%
# %load_ext autoreload
# %autoreload 2

import gym, ray

import os
import fmuSimulation.gymFMU as ExampleFMU
from fmuSimulation.configReader import configReader
import numpy as np
import sys

config = os.path.abspath('Example.cfg')
cfg = configReader(config)
config = cfg.getAgent()
env = ExampleFMU.gymFMU(config['env_config'])

import numpy as np
import torch
import gym
import argparse
import os

import utils
import TD3



# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env_name, seed, eval_episodes=10):
	eval_env = gym.make(env_name)
	eval_env.seed(seed + 100)

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward
# Out:
# No function for resetIO implemented
# No function for obsProcessing implemented
# Incompatible sample time and stop time.
#  Using 10.0 as stop time instead

# %%
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0] 
max_action = float(env.action_space.high[0])

kwargs = {
    "state_dim": state_dim,
    "action_dim": action_dim,
    "max_action": max_action,
    "discount": 0.99,
    "tau": 0.005,
}

max_timesteps = int(1e6)
start_timesteps = int(25e3)
expl_noise = 0.1
max_episode_steps = 1e10
batch_size = 128
eval_freq = 2

policy_noise = 0.2
noise_clip = 0.5
policy_freq = 2
# Target policy smoothing is scaled wrt the action scale
kwargs["policy_noise"] = policy_noise * max_action
kwargs["noise_clip"] = noise_clip * max_action
kwargs["policy_freq"] = policy_freq

policy = TD3.TD3(**kwargs)
#evaluations = [eval_policy(policy, args.env, args.seed)]

# %%
replay_buffer = utils.ReplayBuffer(state_dim, action_dim)

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0

max_timesteps = int(2e6)
for t in range(int(max_timesteps)):
    
    episode_timesteps += 1

    # Select action randomly or according to policy
   # if t < start_timesteps:
    #    action = env.action_space.sample()
    #else:
     #   action = (
      #      policy.select_action(np.array(state))
      #      + np.random.normal(0, max_action * expl_noise, size=action_dim)
      #  ).clip(-max_action, max_action)
   
    action = (
        policy.select_action(np.array(state))
        #+ np.random.normal(0, max_action * expl_noise, size=action_dim)
    ).clip(-max_action, max_action)


    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        print(policy.actor.l3.weight)
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 

    # Evaluate episode
    #if (t + 1) % eval_freq == 0:

        #evaluations.append(eval_policy(policy, args.env, args.seed))
        #np.save(f"./results/{file_name}", evaluations)
        #if args.save_model: policy.save(f"./models/{file_name}")
# Out:
# Episode Num: 1 Episode T: 100 Reward: -523.397
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 2 Episode T: 100 Reward: -610.497
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 3 Episode T: 100 Reward: -435.276
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 4 Episode T: 100 Reward: -411.451
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 5 Episode T: 100 Reward: -499.467
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 6 Episode T: 100 Reward: -540.403
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 7 Episode T: 100 Reward: -609.097
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 8 Episode T: 100 Reward: -630.008
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 9 Episode T: 100 Reward: -540.516
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 10 Episode T: 100 Reward: -714.579
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 11 Episode T: 100 Reward: -682.905
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 12 Episode T: 100 Reward: -518.072
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 13 Episode T: 100 Reward: -811.809
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 14 Episode T: 100 Reward: -515.975
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 15 Episode T: 100 Reward: -873.114
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 16 Episode T: 100 Reward: -500.094
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 17 Episode T: 100 Reward: -515.686
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 18 Episode T: 100 Reward: -467.542
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 19 Episode T: 100 Reward: -450.644
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 20 Episode T: 100 Reward: -711.734
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 21 Episode T: 100 Reward: -514.687
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 22 Episode T: 100 Reward: -546.711
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 23 Episode T: 100 Reward: -868.250
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 24 Episode T: 100 Reward: -682.985
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 25 Episode T: 100 Reward: -547.867
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 26 Episode T: 100 Reward: -489.269
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 27 Episode T: 100 Reward: -743.439
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 28 Episode T: 100 Reward: -659.750
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 29 Episode T: 100 Reward: -596.288
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 30 Episode T: 100 Reward: -635.189
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 31 Episode T: 100 Reward: -550.083
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 32 Episode T: 100 Reward: -468.880
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 33 Episode T: 100 Reward: -381.254
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 34 Episode T: 100 Reward: -728.461
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 35 Episode T: 100 Reward: -572.325
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 36 Episode T: 100 Reward: -494.496
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 37 Episode T: 100 Reward: -549.989
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 38 Episode T: 100 Reward: -735.074
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 39 Episode T: 100 Reward: -391.164
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 40 Episode T: 100 Reward: -521.758
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 41 Episode T: 100 Reward: -434.763
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 42 Episode T: 100 Reward: -464.587
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 43 Episode T: 100 Reward: -634.300
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 44 Episode T: 100 Reward: -321.960
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 45 Episode T: 100 Reward: -432.461
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 46 Episode T: 100 Reward: -475.735
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 47 Episode T: 100 Reward: -742.213
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 48 Episode T: 100 Reward: -624.645
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 49 Episode T: 100 Reward: -767.649
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 50 Episode T: 100 Reward: -610.032
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 51 Episode T: 100 Reward: -507.656
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 52 Episode T: 100 Reward: -500.343
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 53 Episode T: 100 Reward: -435.117
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 54 Episode T: 100 Reward: -475.467
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 55 Episode T: 100 Reward: -444.064
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 56 Episode T: 100 Reward: -725.303
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 57 Episode T: 100 Reward: -432.301
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 58 Episode T: 100 Reward: -476.989
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 59 Episode T: 100 Reward: -470.889
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 60 Episode T: 100 Reward: -522.492
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 61 Episode T: 100 Reward: -568.489
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 62 Episode T: 100 Reward: -559.656
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 63 Episode T: 100 Reward: -857.137
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 64 Episode T: 100 Reward: -445.388
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 65 Episode T: 100 Reward: -470.429
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 66 Episode T: 100 Reward: -432.772
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 67 Episode T: 100 Reward: -242.207
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 68 Episode T: 100 Reward: -727.247
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 69 Episode T: 100 Reward: -751.410
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 70 Episode T: 100 Reward: -743.401
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 71 Episode T: 100 Reward: -463.128
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 72 Episode T: 100 Reward: -927.781
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 73 Episode T: 100 Reward: -448.474
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 74 Episode T: 100 Reward: -400.408
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 75 Episode T: 100 Reward: -549.681
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 76 Episode T: 100 Reward: -552.705
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 77 Episode T: 100 Reward: -540.154
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 78 Episode T: 100 Reward: -366.232
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 79 Episode T: 100 Reward: -485.157
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 80 Episode T: 100 Reward: -560.139
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 81 Episode T: 100 Reward: -592.925
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 82 Episode T: 100 Reward: -713.207
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 83 Episode T: 100 Reward: -783.162
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 84 Episode T: 100 Reward: -678.387
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 85 Episode T: 100 Reward: -359.076
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 86 Episode T: 100 Reward: -1182.653
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 87 Episode T: 100 Reward: -557.503
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 88 Episode T: 100 Reward: -519.351
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 89 Episode T: 100 Reward: -554.859
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 90 Episode T: 100 Reward: -561.905
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 91 Episode T: 100 Reward: -693.944
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 92 Episode T: 100 Reward: -404.327
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 93 Episode T: 100 Reward: -491.058
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 94 Episode T: 100 Reward: -294.223
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 95 Episode T: 100 Reward: -428.908
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 96 Episode T: 100 Reward: -825.214
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 97 Episode T: 100 Reward: -667.673
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 98 Episode T: 100 Reward: -459.745
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 99 Episode T: 100 Reward: -487.181
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 100 Episode T: 100 Reward: -621.872
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 101 Episode T: 100 Reward: -488.319
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 102 Episode T: 100 Reward: -167.343
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 103 Episode T: 100 Reward: -427.386
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 104 Episode T: 100 Reward: -738.919
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 105 Episode T: 100 Reward: -641.339
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 106 Episode T: 100 Reward: -606.525
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 107 Episode T: 100 Reward: -511.463
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 108 Episode T: 100 Reward: -296.128
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 109 Episode T: 100 Reward: -463.669
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 110 Episode T: 100 Reward: -654.111
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 111 Episode T: 100 Reward: -536.002
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 112 Episode T: 100 Reward: -864.922
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 113 Episode T: 100 Reward: -598.557
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 114 Episode T: 100 Reward: -613.312
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 115 Episode T: 100 Reward: -721.318
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 116 Episode T: 100 Reward: -416.716
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 117 Episode T: 100 Reward: -590.344
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 118 Episode T: 100 Reward: -741.042
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 119 Episode T: 100 Reward: -1202.497
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 120 Episode T: 100 Reward: -363.091
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 121 Episode T: 100 Reward: -591.542
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 122 Episode T: 100 Reward: -579.308
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 123 Episode T: 100 Reward: -745.809
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 124 Episode T: 100 Reward: -472.479
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 125 Episode T: 100 Reward: -535.161
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 126 Episode T: 100 Reward: -333.435
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 127 Episode T: 100 Reward: -932.279
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 128 Episode T: 100 Reward: -421.063
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 129 Episode T: 100 Reward: -660.509
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 130 Episode T: 100 Reward: -761.749
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 131 Episode T: 100 Reward: -501.643
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 132 Episode T: 100 Reward: -503.345
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 133 Episode T: 100 Reward: -365.818
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 134 Episode T: 100 Reward: -686.589
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 135 Episode T: 100 Reward: -508.561
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 136 Episode T: 100 Reward: -655.397
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 137 Episode T: 100 Reward: -607.492
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 138 Episode T: 100 Reward: -617.398
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 139 Episode T: 100 Reward: -389.932
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 140 Episode T: 100 Reward: -409.064
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 141 Episode T: 100 Reward: -607.960
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 142 Episode T: 100 Reward: -819.247
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 143 Episode T: 100 Reward: -518.389
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 144 Episode T: 100 Reward: -676.283
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 145 Episode T: 100 Reward: -847.116
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 146 Episode T: 100 Reward: -375.343
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 147 Episode T: 100 Reward: -526.735
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 148 Episode T: 100 Reward: -788.731
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 149 Episode T: 100 Reward: -514.523
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 150 Episode T: 100 Reward: -399.943
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 151 Episode T: 100 Reward: -512.717
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 152 Episode T: 100 Reward: -421.885
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 153 Episode T: 100 Reward: -700.421
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 154 Episode T: 100 Reward: -541.387
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 155 Episode T: 100 Reward: -300.128
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 156 Episode T: 100 Reward: -448.922
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 157 Episode T: 100 Reward: -535.366
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 158 Episode T: 100 Reward: -726.136
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 159 Episode T: 100 Reward: -531.307
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 160 Episode T: 100 Reward: -864.065
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 161 Episode T: 100 Reward: -505.614
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 162 Episode T: 100 Reward: -637.084
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 163 Episode T: 100 Reward: -798.974
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 164 Episode T: 100 Reward: -296.447
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 165 Episode T: 100 Reward: -618.278
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 166 Episode T: 100 Reward: -566.006
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 167 Episode T: 100 Reward: -651.946
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 168 Episode T: 100 Reward: -867.704
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 169 Episode T: 100 Reward: -436.502
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 170 Episode T: 100 Reward: -464.999
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 171 Episode T: 100 Reward: -891.468
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 172 Episode T: 100 Reward: -360.607
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 173 Episode T: 100 Reward: -564.225
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 174 Episode T: 100 Reward: -542.374
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 175 Episode T: 100 Reward: -577.828
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 176 Episode T: 100 Reward: -636.834
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 177 Episode T: 100 Reward: -513.553
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 178 Episode T: 100 Reward: -527.443
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 179 Episode T: 100 Reward: -610.231
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 180 Episode T: 100 Reward: -405.788
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 181 Episode T: 100 Reward: -668.147
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 182 Episode T: 100 Reward: -804.089
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 183 Episode T: 100 Reward: -828.387
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 184 Episode T: 100 Reward: -635.794
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 185 Episode T: 100 Reward: -679.899
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 186 Episode T: 100 Reward: -664.493
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 187 Episode T: 100 Reward: -586.596
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 188 Episode T: 100 Reward: -739.573
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 189 Episode T: 100 Reward: -481.048
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 190 Episode T: 100 Reward: -436.409
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 191 Episode T: 100 Reward: -508.120
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 192 Episode T: 100 Reward: -375.348
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 193 Episode T: 100 Reward: -852.280
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 194 Episode T: 100 Reward: -800.822
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 195 Episode T: 100 Reward: -500.174
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 196 Episode T: 100 Reward: -464.295
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 197 Episode T: 100 Reward: -717.697
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 198 Episode T: 100 Reward: -584.382
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 199 Episode T: 100 Reward: -703.529
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 200 Episode T: 100 Reward: -400.596
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 201 Episode T: 100 Reward: -528.508
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 202 Episode T: 100 Reward: -646.412
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 203 Episode T: 100 Reward: -878.926
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 204 Episode T: 100 Reward: -486.740
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 205 Episode T: 100 Reward: -525.574
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 206 Episode T: 100 Reward: -459.292
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 207 Episode T: 100 Reward: -362.775
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 208 Episode T: 100 Reward: -784.732
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 209 Episode T: 100 Reward: -544.952
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 210 Episode T: 100 Reward: -593.216
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 211 Episode T: 100 Reward: -572.749
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 212 Episode T: 100 Reward: -489.770
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 213 Episode T: 100 Reward: -433.248
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 214 Episode T: 100 Reward: -1091.746
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 215 Episode T: 100 Reward: -528.027
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 216 Episode T: 100 Reward: -797.255
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 217 Episode T: 100 Reward: -355.297
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 218 Episode T: 100 Reward: -477.454
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 219 Episode T: 100 Reward: -485.576
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 220 Episode T: 100 Reward: -483.942
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 221 Episode T: 100 Reward: -490.153
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 222 Episode T: 100 Reward: -738.402
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 223 Episode T: 100 Reward: -710.011
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 224 Episode T: 100 Reward: -723.072
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 225 Episode T: 100 Reward: -421.898
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 226 Episode T: 100 Reward: -771.501
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 227 Episode T: 100 Reward: -418.906
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 228 Episode T: 100 Reward: -584.229
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 229 Episode T: 100 Reward: -520.370
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 230 Episode T: 100 Reward: -334.777
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 231 Episode T: 100 Reward: -643.021
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 232 Episode T: 100 Reward: -652.226
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 233 Episode T: 100 Reward: -835.782
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 234 Episode T: 100 Reward: -609.329
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 235 Episode T: 100 Reward: -553.545
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 236 Episode T: 100 Reward: -367.465
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 237 Episode T: 100 Reward: -395.614
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 238 Episode T: 100 Reward: -609.995
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 239 Episode T: 100 Reward: -621.604
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 240 Episode T: 100 Reward: -400.239
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 241 Episode T: 100 Reward: -668.591
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 242 Episode T: 100 Reward: -628.936
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 243 Episode T: 100 Reward: -447.487
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 244 Episode T: 100 Reward: -531.556
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 245 Episode T: 100 Reward: -720.565
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 246 Episode T: 100 Reward: -824.992
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 247 Episode T: 100 Reward: -814.599
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 248 Episode T: 100 Reward: -543.416
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 249 Episode T: 100 Reward: -342.159
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# Episode Num: 250 Episode T: 100 Reward: -549.512
# Parameter containing:
# tensor([[2.0000e+00, 1.0000e-03]], requires_grad=True)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [3], line 40
#      38 # Train agent after collecting sufficient data
#      39 if t >= start_timesteps:
# ---> 40     policy.train(replay_buffer, batch_size)
#      42 if done:
#      43     # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
#      44     print(f"Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
#
# File ~/git/dissertation/framework/01-FMU/python/04-TD3/TD3.py:120, in TD3.train(self, replay_buffer, batch_size)
#     113 with torch.no_grad():
#     114 	# Select action according to policy and add clipped noise
#     115 	noise = (
#     116 		torch.randn_like(action) * self.policy_noise
#     117 	).clamp(-self.noise_clip, self.noise_clip)
#     119 	next_action = (
# --> 120 		self.actor_target(next_state) + noise
#     121 	).clamp(-self.max_action, self.max_action)
#     123 	# Compute the target Q value
#     124 	target_Q1, target_Q2 = self.critic_target(next_state, next_action)
#
# File ~/git/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git/dissertation/framework/01-FMU/python/04-TD3/TD3.py:30, in Actor.forward(self, state)
#      29 def forward(self, state):
# ---> 30 	return self.l3(state)
#
# File ~/git/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git/env/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat2 in method wrapper_mm)

# %%
replay_buffer = utils.ReplayBuffer(state_dim, action_dim)

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0


for t in range(int(2000)):
    
    episode_timesteps += 1

    # Select action randomly or according to policy
    #if t < start_timesteps:
    #action = env.action_space.sample()
    #else:
    action = (
        policy.select_action(np.array(state))
        #+ np.random.normal(0, max_action * expl_noise, size=action_dim)
    ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        print(policy.actor.l3.weight)
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 
        break

    # Evaluate episode
    #if (t + 1) % eval_freq == 0:

        #evaluations.append(eval_policy(policy, args.env, args.seed))
        #np.save(f"./results/{file_name}", evaluations)
        #if args.save_model: policy.save(f"./models/{file_name}")
# Out:
# Total T: 2000 Episode Num: 1 Episode T: 2000 Reward: -834.416
# Parameter containing:
# tensor([[1.1719, 0.3397]], device='cuda:0', requires_grad=True)

# %%
import matplotlib.pyplot as plt
plt.plot(replay_buffer.action[:2000])

# %%
plt.plot(replay_buffer.state[:2000,0], label='error')

# %%
plt.plot(replay_buffer.state[:2000,1], label='Integral')

# %%
from ray.rllib.utils.torch_utils import convert_to_torch_tensor
import numpy as np

# %%
10+np.random.randn()
# Out:
# 10.92734217910362

# %%
with torch.no_grad():
    policy.actor.l3.weight[0]= 2 * policy.actor.l3.weight[0][0].abs()
