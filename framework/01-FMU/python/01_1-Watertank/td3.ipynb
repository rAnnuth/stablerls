# %%
# %load_ext autoreload
# %autoreload 2

import gym, ray

import os
import fmuSimulation.gymFMU as ExampleFMU
from fmuSimulation.configReader import configReader
import numpy as np
import sys

config = os.path.abspath('Example.cfg')
cfg = configReader(config)
config = cfg.getAgent()
env = ExampleFMU.gymFMU(config['env_config'])

import numpy as np
import torch
import gym
import argparse
import os

import utils
import TD3



# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env_name, seed, eval_episodes=10):
	eval_env = gym.make(env_name)
	eval_env.seed(seed + 100)

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward
# Out:
# No function for resetIO implemented
# Incompatible sample time and stop time.
#  Using 10.0 as stop time instead
# Incompatible sample time and action interval.
#  Using 10000000.0 as interval instead

# %%
state_dim = env.observation_space.shape[1]
action_dim = env.action_space.shape[0] 
max_action = float(env.action_space.high[0])

kwargs = {
    "state_dim": state_dim,
    "action_dim": action_dim,
    "max_action": max_action,
    "discount": 0.99,
    "tau": 0.005,
}

max_timesteps = int(1e6)
start_timesteps = int(25e3)
expl_noise = 0.1
max_episode_steps = 1e10
batch_size = 128
eval_freq = 2

policy_noise = 0.2
noise_clip = 0.5
policy_freq = 2
# Target policy smoothing is scaled wrt the action scale
kwargs["policy_noise"] = policy_noise * max_action
kwargs["noise_clip"] = noise_clip * max_action
kwargs["policy_freq"] = policy_freq

policy = TD3.TD3(**kwargs)
#evaluations = [eval_policy(policy, args.env, args.seed)]

# %%
replay_buffer = utils.ReplayBuffer(state_dim, action_dim)

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0

max_timesteps = int(2e6)
for t in range(int(max_timesteps)):
    
    episode_timesteps += 1

    # Select action randomly or according to policy
   # if t < start_timesteps:
    #    action = env.action_space.sample()
    #else:
     #   action = (
      #      policy.select_action(np.array(state))
      #      + np.random.normal(0, max_action * expl_noise, size=action_dim)
      #  ).clip(-max_action, max_action)
   
    action = (
        policy.select_action(np.array(state))
        #+ np.random.normal(0, max_action * expl_noise, size=action_dim)
    ).clip(0, max_action)


    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        print(action)
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 

    # Evaluate episode
    #if (t + 1) % eval_freq == 0:
        #evaluations.append(eval_policy(policy, args.env, args.seed))
        #np.save(f"./results/{file_name}", evaluations)
        #if args.save_model: policy.save(f"./models/{file_name}")
# Out:
# inf observation
# Episode Num: 1 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 2 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 3 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 4 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 5 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num:
Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1131 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1132 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1133 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1134 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1135 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1136 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1137 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1138 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1139 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1140 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1141 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1142 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1143 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1144 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1145 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1146 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1147 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1148 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1149 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1150 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1151 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1152 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1153 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1154 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1155 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1156 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1157 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1158 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1159 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1160 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1161 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1162 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1163 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1164 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1165 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1166 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1167 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1168 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1169 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1170 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1171 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1172 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1173 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1174 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1175 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1176 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1177 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1178 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1179 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1180 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1181 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1182 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1183 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1184 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1185 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1186 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1187 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1188 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1189 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1190 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1191 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1192 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1193 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1194 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1195 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1196 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1197 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1198 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1199 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1200 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1201 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1202 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1203 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1204 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1205 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1206 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1207 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1208 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1209 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1210 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1211 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1212 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1213 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1214 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1215 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1216 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1217 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1218 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1219 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1220 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1221 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1222 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]
# inf observation
# Episode Num: 1223 Episode T: 1 Reward: nan
# [ 1.9954371 -2.0498497]

# %%
replay_buffer = utils.ReplayBuffer(state_dim, action_dim)

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0


for t in range(int(2000)):
    
    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < start_timesteps:
        action = env.action_space.sample()
    else:
        action = (
        policy.select_action(np.array(state))
        + np.random.normal(0, max_action * expl_noise, size=action_dim)
    ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < max_episode_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= start_timesteps:
        policy.train(replay_buffer, batch_size)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        print(action)
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 
        

    # Evaluate episode
    #if (t + 1) % eval_freq == 0:

        #evaluations.append(eval_policy(policy, args.env, args.seed))
        #np.save(f"./results/{file_name}", evaluations)
        #if args.save_model: policy.save(f"./models/{file_name}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 27
#      24 done_bool = float(done) if episode_timesteps < max_episode_steps else 0
#      26 # Store data in replay buffer
# ---> 27 replay_buffer.add([state], action, next_state, reward, done_bool)
#      29 state = next_state
#      30 episode_reward += reward
#
# File ~/git/dissertation/framework/01-FMU/python/01_1-Watertank/utils.py:21, in ReplayBuffer.add(self, state, action, next_state, reward, done)
#      20 def add(self, state, action, next_state, reward, done):
# ---> 21 	self.state[self.ptr] = state
#      22 	self.action[self.ptr] = action
#      23 	self.next_state[self.ptr] = next_state
#
# ValueError: setting an array element with a sequence. The requested array would exceed the maximum number of dimension of 1.

# %%
import matplotlib.pyplot as plt
plt.plot(replay_buffer.action[:2000])

# %%
plt.plot(replay_buffer.state[:2000,0], label='error')

# %%
plt.plot(replay_buffer.state[:2000,1], label='Integral')

# %%
from ray.rllib.utils.torch_utils import convert_to_torch_tensor
import numpy as np

# %%
10+np.random.randn()
# Out:
# 9.734897202107904

# %%
with torch.no_grad():
    policy.actor.l3.weight[0]= 2 * policy.actor.l3.weight[0][0].abs()
