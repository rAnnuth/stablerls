# %%
try:
    ray.shutdown()
except:
    pass

# %load_ext autoreload
# %autoreload 2

import gym, ray
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms import sac
from ray.rllib.algorithms import pg
from ray.rllib.algorithms import a3c
from ray.rllib.algorithms import td3

ray.init()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2022-11-25 16:48:44,853	INFO worker.py:1528 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.9.15', ray_version='2.1.0', ray_commit='be49bde7ee4f6adb3f8710aee0665c27f9f0bb62', address_info={'node_ip_address': '134.28.38.224', 'raylet_ip_address': '134.28.38.224', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-11-25_16-48-43_235764_417813/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-11-25_16-48-43_235764_417813/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2022-11-25_16-48-43_235764_417813', 'metrics_export_port': 59695, 'gcs_address': '134.28.38.224:64458', 'address': '134.28.38.224:64458', 'dashboard_agent_listen_port': 52365, 'node_id': '81fd837920f8687021564f3856210c58d781fd73a8eab1a56f05af19'})

# %%
import os
import fmuSimulation.gymFMU as ExampleFMU
from fmuSimulation.configReader import configReader
import numpy as np
import sys
from torchModel import customTorchModel, FullyConnectedNetwork
from ExampleTorch import FullyConnectedNetwork
#from ExampleTF import Keras_FullyConnectedNetwork as fcTF

config = os.path.abspath('Example.cfg')
cfg = configReader(config)
config = cfg.getAgent()
#if 0:   
config['framework'] = 'torch'
    #agent = ppo.PPO(env=ExampleFMU.gymFMU, config={"env_config": config, "num_workers": 1, "num_gpus": 0})
#config['model'] = {}
#config['model']['custom_model'] = FullyConnectedNetwork
#config['model']['custom_model'] = customTorchModel
#config['model']['fcnet_hiddens'] = [2]
#
#config['model']['no_final_linear'] = False
#config['model']['custom_model'] = MyKerasModel
#agent = pg.PG(env=ExampleFMU.gymFMU, config=config)

agent = td3.TD3(env=ExampleFMU.gymFMU, config=config)
#agent = ppo.PPO(env=ExampleFMU.gymFMU, config=config)
# Out:
# (RolloutWorker pid=447215) No function for resetIO implemented
# (RolloutWorker pid=447215) Incompatible sample time and stop time.
# (RolloutWorker pid=447215)  Using 10.0 as stop time instead
# (RolloutWorker pid=447215) Incompatible sample time and action interval.
# (RolloutWorker pid=447215)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447216) No function for resetIO implemented
# (RolloutWorker pid=447216) Incompatible sample time and stop time.
# (RolloutWorker pid=447216)  Using 10.0 as stop time instead
# (RolloutWorker pid=447216) Incompatible sample time and action interval.
# (RolloutWorker pid=447216)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447215) 2022-11-25 16:48:49,676	WARNING env.py:147 -- Your env doesn't have a .spec.max_episode_steps attribute. This is fine if you have set 'horizon' in your config dictionary, or `soft_horizon`. However, if you haven't, 'horizon' will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=447219) No function for resetIO implemented
# (RolloutWorker pid=447219) Incompatible sample time and stop time.
# (RolloutWorker pid=447219)  Using 10.0 as stop time instead
# (RolloutWorker pid=447219) Incompatible sample time and action interval.
# (RolloutWorker pid=447219)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447221) No function for resetIO implemented
# (RolloutWorker pid=447218) No function for resetIO implemented
# (RolloutWorker pid=447225) No function for resetIO implemented
# (RolloutWorker pid=447229) No function for resetIO implemented
# (RolloutWorker pid=447229) Incompatible sample time and stop time.
# (RolloutWorker pid=447229)  Using 10.0 as stop time instead
# (RolloutWorker pid=447229) Incompatible sample time and action interval.
# (RolloutWorker pid=447229)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447231) No function for resetIO implemented
# (RolloutWorker pid=447231) Incompatible sample time and stop time.
# (RolloutWorker pid=447231)  Using 10.0 as stop time instead
# (RolloutWorker pid=447231) Incompatible sample time and action interval.
# (RolloutWorker pid=447231)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447224) No function for resetIO implemented
# (RolloutWorker pid=447224) Incompatible sample time and stop time.
# (RolloutWorker pid=447224)  Using 10.0 as stop time instead
# (RolloutWorker pid=447224) Incompatible sample time and action interval.
# (RolloutWorker pid=447224)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447221) Incompatible sample time and stop time.
# (RolloutWorker pid=447221)  Using 10.0 as stop time instead
# (RolloutWorker pid=447221) Incompatible sample time and action interval.
# (RolloutWorker pid=447221)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447222) No function for resetIO implemented
# (RolloutWorker pid=447222) Incompatible sample time and stop time.
# (RolloutWorker pid=447222)  Using 10.0 as stop time instead
# (RolloutWorker pid=447222) Incompatible sample time and action interval.
# (RolloutWorker pid=447222)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447218) Incompatible sample time and stop time.
# (RolloutWorker pid=447218)  Using 10.0 as stop time instead
# (RolloutWorker pid=447218) Incompatible sample time and action interval.
# (RolloutWorker pid=447218)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447225) Incompatible sample time and stop time.
# (RolloutWorker pid=447225)  Using 10.0 as stop time instead
# (RolloutWorker pid=447225) Incompatible sample time and action interval.
# (RolloutWorker pid=447225)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447226) No function for resetIO implemented
# (RolloutWorker pid=447226) Incompatible sample time and stop time.
# (RolloutWorker pid=447226)  Using 10.0 as stop time instead
# (RolloutWorker pid=447226) Incompatible sample time and action interval.
# (RolloutWorker pid=447226)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447223) No function for resetIO implemented
# (RolloutWorker pid=447233) No function for resetIO implemented
# (RolloutWorker pid=447233) Incompatible sample time and stop time.
# (RolloutWorker pid=447233)  Using 10.0 as stop time instead
# (RolloutWorker pid=447233) Incompatible sample time and action interval.
# (RolloutWorker pid=447233)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447228) No function for resetIO implemented
# (RolloutWorker pid=447228) Incompatible sample time and stop time.
# (RolloutWorker pid=447228)  Using 10.0 as stop time instead
# (RolloutWorker pid=447228) Incompatible sample time and action interval.
# (RolloutWorker pid=447228)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447217) No function for resetIO implemented
# (RolloutWorker pid=447234) No function for resetIO implemented
# (RolloutWorker pid=447234) Incompatible sample time and stop time.
# (RolloutWorker pid=447234)  Using 10.0 as stop time instead
# (RolloutWorker pid=447234) Incompatible sample time and action interval.
# (RolloutWorker pid=447234)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447217) Incompatible sample time and stop time.
# (RolloutWorker pid=447217)  Using 10.0 as stop time instead
# (RolloutWorker pid=447217) Incompatible sample time and action interval.
# (RolloutWorker pid=447217)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447223) Incompatible sample time and stop time.
# (RolloutWorker pid=447223)  Using 10.0 as stop time instead
# (RolloutWorker pid=447223) Incompatible sample time and action interval.
# (RolloutWorker pid=447223)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447227) No function for resetIO implemented
# (RolloutWorker pid=447227) Incompatible sample time and stop time.
# (RolloutWorker pid=447227)  Using 10.0 as stop time instead
# (RolloutWorker pid=447227) Incompatible sample time and action interval.
# (RolloutWorker pid=447227)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447230) No function for resetIO implemented
# (RolloutWorker pid=447230) Incompatible sample time and stop time.
# (RolloutWorker pid=447230)  Using 10.0 as stop time instead
# (RolloutWorker pid=447230) Incompatible sample time and action interval.
# (RolloutWorker pid=447230)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447220) No function for resetIO implemented
# (RolloutWorker pid=447220) Incompatible sample time and stop time.
# (RolloutWorker pid=447220)  Using 10.0 as stop time instead
# (RolloutWorker pid=447220) Incompatible sample time and action interval.
# (RolloutWorker pid=447220)  Using 10000000.0 as interval instead
# (RolloutWorker pid=447232) No function for resetIO implemented
# (RolloutWorker pid=447232) Incompatible sample time and stop time.
# (RolloutWorker pid=447232)  Using 10.0 as stop time instead
# (RolloutWorker pid=447232) Incompatible sample time and action interval.
# (RolloutWorker pid=447232)  Using 10000000.0 as interval instead

# %%
N_ITER = 1000
s = "{:3d} reward {:6.2f}/{:6.2f}/{:6.2f} len {:6.2f} saved {}"

for n in range(N_ITER):
    result = agent.train()
    file_name = agent.save()

    print(s.format(
        n + 1,
        result["episode_reward_min"],
        result["episode_reward_mean"],
        result["episode_reward_max"],
        result["episode_len_mean"],
        file_name
        ))
# Out:
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447219) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447218) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447230) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447229) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447227) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447231) inf observation
# (RolloutWorker pid=447223) inf observation
# (RolloutWorker pid=447215) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447233) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447232) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447234) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447225) inf observation
# (RolloutWorker pid=447228) inf observation
# (RolloutWorker pid=447221) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447222) inf observation
# (RolloutWorker pid=447226) inf observation
# (RolloutWorker pid=447217) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447216) inf observation
# (RolloutWorker pid=447224) inf observation
# (RolloutWorker pid=447220) inf observation
# (RolloutWorker pid=447224) inf observation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/policy/torch_policy_v2.py:1107, in TorchPolicyV2._multi_gpu_parallel_grad_calc.<locals>._worker(shard_idx, model, sample_batch, device)
#    1103 with NullContextManager() if device.type == "cpu" else torch.cuda.device(  # noqa: E501
#    1104     device
#    1105 ):
#    1106     loss_out = force_list(
# -> 1107         self.loss(model, self.dist_class, sample_batch)
#    1108     )
#    1110     # Call Model's custom-loss with Policy loss outputs and
#    1111     # train_batch.
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/ppo/ppo_torch_policy.py:88, in PPOTorchPolicy.loss(self, model, dist_class, train_batch)
#      87 logits, state = model(train_batch)
# ---> 88 curr_action_dist = dist_class(logits, model)
#      90 # RNN case: Mask away 0-padded chunks at end of time axis.
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/models/torch/torch_action_dist.py:250, in TorchDiagGaussian.__init__(self, inputs, model, action_space)
#     249 self.log_std = log_std
# --> 250 self.dist = torch.distributions.normal.Normal(mean, torch.exp(log_std))
#     251 # Remember to squeeze action samples in case action space is Box(shape)
#
# File ~/git/env/lib/python3.9/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      55     batch_shape = self.loc.size()
# ---> 56 super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#
# File ~/git/env/lib/python3.9/site-packages/torch/distributions/distribution.py:56, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      55         if not valid.all():
# ---> 56             raise ValueError(
#      57                 f"Expected parameter {param} "
#      58                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      59                 f"of distribution {repr(self)} "
#      60                 f"to satisfy the constraint {repr(constraint)}, "
#      61                 f"but found invalid values:\n{value}"
#      62             )
#      63 super(Distribution, self).__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (128, 2)) of distribution Normal(loc: torch.Size([128, 2]), scale: torch.Size([128, 2])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan]], device='cuda:0', grad_fn=<SplitBackward0>)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 5
#       2 s = "{:3d} reward {:6.2f}/{:6.2f}/{:6.2f} len {:6.2f} saved {}"
#       4 for n in range(N_ITER):
# ----> 5     result = agent.train()
#       6     file_name = agent.save()
#       8     print(s.format(
#       9         n + 1,
#      10         result["episode_reward_min"],
#    (...)
#      14         file_name
#      15         ))
#
# File ~/git/env/lib/python3.9/site-packages/ray/tune/trainable/trainable.py:355, in Trainable.train(self)
#     353 except Exception as e:
#     354     skipped = skip_exceptions(e)
# --> 355     raise skipped from exception_cause(skipped)
#     357 assert isinstance(result, dict), "step() needs to return a dict."
#     359 # We do not modify internal state nor update this result if duplicate.
#
# File ~/git/env/lib/python3.9/site-packages/ray/tune/trainable/trainable.py:352, in Trainable.train(self)
#     350 start = time.time()
#     351 try:
# --> 352     result = self.step()
#     353 except Exception as e:
#     354     skipped = skip_exceptions(e)
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:772, in Algorithm.step(self)
#     764     (
#     765         results,
#     766         train_iter_ctx,
#     767     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     768 # - No evaluation necessary, just run the next training iteration.
#     769 # - We have to evaluate in this training iteration, but no parallelism ->
#     770 #   evaluate after the training iteration is entirely done.
#     771 else:
# --> 772     results, train_iter_ctx = self._run_one_training_iteration()
#     774 # Sequential: Train (already done above), then evaluate.
#     775 if evaluate_this_iter and not self.config["evaluation_parallel_to_training"]:
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:2953, in Algorithm._run_one_training_iteration(self)
#    2951         # In case of any failures, try to ignore/recover the failed workers.
#    2952         except Exception as e:
# -> 2953             num_recreated += self.try_recover_from_step_attempt(
#    2954                 error=e,
#    2955                 worker_set=self.workers,
#    2956                 ignore=self.config["ignore_worker_failures"],
#    2957                 recreate=self.config["recreate_failed_workers"],
#    2958             )
#    2959     results["num_recreated_workers"] = num_recreated
#    2961 return results, train_iter_ctx
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:2622, in Algorithm.try_recover_from_step_attempt(self, error, worker_set, ignore, recreate)
#    2618 # Any other exception.
#    2619 else:
#    2620     # Allow logs messages to propagate.
#    2621     time.sleep(0.5)
# -> 2622     raise error
#    2624 removed_workers, new_workers = [], []
#    2625 # Search for failed workers and try to recover (restart) them.
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/algorithm.py:2948, in Algorithm._run_one_training_iteration(self)
#    2946 with self._timers[TRAINING_ITERATION_TIMER]:
#    2947     if self.config["_disable_execution_plan_api"]:
# -> 2948         results = self.training_step()
#    2949     else:
#    2950         results = next(self.train_exec_impl)
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/ppo/ppo.py:421, in PPO.training_step(self)
#     419     train_results = train_one_step(self, train_batch)
#     420 else:
# --> 421     train_results = multi_gpu_train_one_step(self, train_batch)
#     423 global_vars = {
#     424     "timestep": self._counters[NUM_AGENT_STEPS_SAMPLED],
#     425 }
#     427 # Update weights - after learning on the local worker - on all remote
#     428 # workers.
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/execution/train_ops.py:176, in multi_gpu_train_one_step(algorithm, train_batch)
#     171         permutation = np.random.permutation(num_batches)
#     172         for batch_index in range(num_batches):
#     173             # Learn on the pre-loaded data in the buffer.
#     174             # Note: For minibatch SGD, the data is an offset into
#     175             # the pre-loaded entire train batch.
# --> 176             results = policy.learn_on_loaded_batch(
#     177                 permutation[batch_index] * per_device_batch_size, buffer_index=0
#     178             )
#     180             learner_info_builder.add_learn_on_batch_results(results, policy_id)
#     182 # Tower reduce and finalize results.
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/policy/torch_policy_v2.py:742, in TorchPolicyV2.learn_on_loaded_batch(self, offset, buffer_index)
#     739     batch_fetches[f"tower_{i}"] = {"custom_metrics": custom_metrics}
#     741 # Do the (maybe parallelized) gradient calculation step.
# --> 742 tower_outputs = self._multi_gpu_parallel_grad_calc(device_batches)
#     744 # Mean-reduce gradients over GPU-towers (do this on CPU: self.device).
#     745 all_grads = []
#
# File ~/git/env/lib/python3.9/site-packages/ray/rllib/policy/torch_policy_v2.py:1191, in TorchPolicyV2._multi_gpu_parallel_grad_calc(self, sample_batches)
#    1189         last_result = results[len(results) - 1]
#    1190         if isinstance(last_result[0], ValueError):
# -> 1191             raise last_result[0] from last_result[1]
#    1192 # Multi device (GPU) case: Parallelize via threads.
#    1193 else:
#    1194     threads = [
#    1195         threading.Thread(
#    1196             target=_worker, args=(shard_idx, model, sample_batch, device)
#    (...)
#    1200         )
#    1201     ]
#
# ValueError: Expected parameter loc (Tensor of shape (128, 2)) of distribution Normal(loc: torch.Size([128, 2]), scale: torch.Size([128, 2])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan]], device='cuda:0', grad_fn=<SplitBackward0>)
#  tracebackTraceback (most recent call last):
#   File "/home/robert/git/env/lib/python3.9/site-packages/ray/rllib/policy/torch_policy_v2.py", line 1107, in _worker
#     self.loss(model, self.dist_class, sample_batch)
#   File "/home/robert/git/env/lib/python3.9/site-packages/ray/rllib/algorithms/ppo/ppo_torch_policy.py", line 88, in loss
#     curr_action_dist = dist_class(logits, model)
#   File "/home/robert/git/env/lib/python3.9/site-packages/ray/rllib/models/torch/torch_action_dist.py", line 250, in __init__
#     self.dist = torch.distributions.normal.Normal(mean, torch.exp(log_std))
#   File "/home/robert/git/env/lib/python3.9/site-packages/torch/distributions/normal.py", line 56, in __init__
#     super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#   File "/home/robert/git/env/lib/python3.9/site-packages/torch/distributions/distribution.py", line 56, in __init__
#     raise ValueError(
# ValueError: Expected parameter loc (Tensor of shape (128, 2)) of distribution Normal(loc: torch.Size([128, 2]), scale: torch.Size([128, 2])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan],
#         [nan, nan]], device='cuda:0', grad_fn=<SplitBackward0>)
#
# In tower 0 on device cuda:0

# %%
#a = getObservationSpace()
agent.compute_single_action(np.full([1,1001], 0, dtype=np.float32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 #a = getObservationSpace()
# ----> 2 agent.compute_single_action(np.full([1,1001], 0, dtype=np.float32))
#
# NameError: name 'agent' is not defined

# %%
from gym import spaces
def getObservationSpace():
    low = np.array([-np.inf, -np.inf, -np.inf]).astype(np.float32)
    high = np.array([np.inf, np.inf, np.inf]).astype(np.float32)
    #self.isDiscrete = False # np.int64 for discrete or np.float32 for cont.
#   self.obsType = np.int64 # np.int64 for discrete or np.float32 for cont.
    return spaces.Box(low, high)

# %%
agent.get_policy().model.base_model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 agent.get_policy().model.base_model.summary()
#
# File ~/git/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1265, in Module.__getattr__(self, name)
#    1263     if name in modules:
#    1264         return modules[name]
# -> 1265 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1266     type(self).__name__, name))
#
# AttributeError: 'TorchNoopModel_as_DDPGTorchModel' object has no attribute 'base_model'

# %%
agent2.get_weights()
# Out:
# {'default_policy': {'_hidden_layers.0.weight': array([[-0.47284952, -0.6123957 ]], dtype=float32),
#   '_value_branch._model.0.weight': array([[-0.0009343 ,  0.00995626]], dtype=float32),
#   '_value_branch._model.0.bias': array([0.], dtype=float32)}}

# %%
import pdb
pdb.set_trace()
agent.compute_single_action([1,1])
# Out:
# --Return--
# None
# > /tmp/ipykernel_66968/4057848078.py(2)<module>()
#       1 import pdb
# ----> 2 pdb.set_trace()
#       3 agent.compute_single_action([1,1])

# %%
agent.get_policy().
# Out:
# A3CTorchPolicy
