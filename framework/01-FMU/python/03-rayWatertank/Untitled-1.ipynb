# %%
import logging
from typing import Any, Dict, List, Optional, Type, Union

from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.algorithms.algorithm_config import AlgorithmConfig, NotProvided
from ray.rllib.evaluation.rollout_worker import RolloutWorker
from ray.rllib.policy.policy import Policy
from ray.rllib.utils.annotations import override
from ray.rllib.utils.deprecation import Deprecated
from ray.rllib.utils.metrics import (
    APPLY_GRADS_TIMER,
    GRAD_WAIT_TIMER,
    NUM_AGENT_STEPS_SAMPLED,
    NUM_AGENT_STEPS_TRAINED,
    NUM_ENV_STEPS_SAMPLED,
    NUM_ENV_STEPS_TRAINED,
    SYNCH_WORKER_WEIGHTS_TIMER,
)
from ray.rllib.utils.metrics.learner_info import LearnerInfoBuilder
from ray.rllib.utils.typing import ResultDict
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Untitled-1.ipynb Zelle 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=1'>2</a> from typing import Any, Dict, List, Optional, Type, Union
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a> from ray.rllib.algorithms.algorithm import Algorithm
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=4'>5</a> from ray.rllib.algorithms.algorithm_config import AlgorithmConfig, NotProvided
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=5'>6</a> from ray.rllib.evaluation.rollout_worker import RolloutWorker
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=6'>7</a> from ray.rllib.policy.policy import Policy
#
# ImportError: cannot import name 'NotProvided' from 'ray.rllib.algorithms.algorithm_config' (c:\Users\Robert\git\env\lib\site-packages\ray\rllib\algorithms\algorithm_config.py)

# %%
from ray.rllib.algorithms.ppo import PPOConfig

config = (  # 1. Configure the algorithm,
    PPOConfig()
    .environment("Taxi-v3")
    .rollouts(num_rollout_workers=2)
    .framework("tf2")
    .training(model={"fcnet_hiddens": [64, 64]})
    .evaluation(evaluation_num_workers=1)
)

algo = config.build()  # 2. build the algorithm,

for _ in range(5):
    print(algo.train())  # 3. train it,

algo.evaluate()  # 4. and evaluate it.
# Out:
# lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.
# Could not instantiate TBXLogger: No module named 'tensorboardX'.
# 2022-11-17 16:20:20,792	WARNING algorithm.py:2531 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2022-11-17 16:20:23,028	INFO worker.py:1528 -- Started a local Ray instance.
# (pid=13776) 2022-11-17 16:20:27,263	WARNING compression.py:17 -- lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.
# (pid=39828) 2022-11-17 16:20:27,224	WARNING compression.py:17 -- lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.
# (RolloutWorker pid=13776) 2022-11-17 16:20:27,365	WARNING env.py:159 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=13776) 2022-11-17 16:20:27,422	ERROR worker.py:763 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=13776, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000025666BC32E0>)
# (RolloutWorker pid=13776) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) First structure: type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) Second structure: type=int str=443
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) More specifically: Substructure "type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=443" is not
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) ray::RolloutWorker.__init__() (pid=13776, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000025666BC32E0>)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
# (RolloutWorker pid=13776)     check_gym_environments(env)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
# (RolloutWorker pid=13776)     temp_sampled_reset_obs = convert_element_to_space_type(
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
# (RolloutWorker pid=13776)     return tree.map_structure(map_, element, sampled_element, check_types=False)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
# (RolloutWorker pid=13776)     assert_same_structure(structures[0], other, check_types=check_types)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
# (RolloutWorker pid=13776)     raise type(e)("%s\n"
# (RolloutWorker pid=13776) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) First structure: type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) Second structure: type=int str=443
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) More specifically: Substructure "type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=443" is not
# (RolloutWorker pid=13776) Entire first structure:
# (RolloutWorker pid=13776) (., {'prob': ., 'action_mask': .})
# (RolloutWorker pid=13776) Entire second structure:
# (RolloutWorker pid=13776) .
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) ray::RolloutWorker.__init__() (pid=13776, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000025666BC32E0>)
# (RolloutWorker pid=13776)   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
# (RolloutWorker pid=13776)   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
# (RolloutWorker pid=13776)   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
# (RolloutWorker pid=13776)   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
# (RolloutWorker pid=13776)   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
# (RolloutWorker pid=13776)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (RolloutWorker pid=13776)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 497, in __init__
# (RolloutWorker pid=13776)     check_env(self.env)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 88, in check_env
# (RolloutWorker pid=13776)     raise ValueError(
# (RolloutWorker pid=13776) ValueError: Traceback (most recent call last):
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 280, in assert_same_structure
# (RolloutWorker pid=13776)     _tree.assert_same_structure(a, b, check_types)
# (RolloutWorker pid=13776) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) First structure: type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) Second structure: type=int str=443
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) More specifically: Substructure "type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=443" is not
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) ray::RolloutWorker.__init__() (pid=13776, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000025666BC32E0>)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
# (RolloutWorker pid=13776)     check_gym_environments(env)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
# (RolloutWorker pid=13776)     temp_sampled_reset_obs = convert_element_to_space_type(
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
# (RolloutWorker pid=13776)     return tree.map_structure(map_, element, sampled_element, check_types=False)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
# (RolloutWorker pid=13776)     assert_same_structure(structures[0], other, check_types=check_types)
# (RolloutWorker pid=13776)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
# (RolloutWorker pid=13776)     raise type(e)("%s\n"
# (RolloutWorker pid=13776) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) First structure: type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) Second structure: type=int str=443
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) More specifically: Substructure "type=tuple str=(48, {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=443" is not
# (RolloutWorker pid=13776) Entire first structure:
# (RolloutWorker pid=13776) (., {'prob': ., 'action_mask': .})
# (RolloutWorker pid=13776) Entire second structure:
# (RolloutWorker pid=13776) .
# (RolloutWorker pid=13776)
# (RolloutWorker pid=13776) The above error has been found in your environment! We've added a module for checking your custom environments. It may cause your experiment to fail if your environment is not set up correctly. You can disable this behavior by setting `disable_env_checking=True` in your environment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env([env]).
# (RolloutWorker pid=39828) 2022-11-17 16:20:27,384	ERROR worker.py:763 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
# (RolloutWorker pid=39828) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) Second structure: type=int str=226
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
# (RolloutWorker pid=39828)     check_gym_environments(env)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
# (RolloutWorker pid=39828)     temp_sampled_reset_obs = convert_element_to_space_type(
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
# (RolloutWorker pid=39828)     return tree.map_structure(map_, element, sampled_element, check_types=False)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
# (RolloutWorker pid=39828)     assert_same_structure(structures[0], other, check_types=check_types)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
# (RolloutWorker pid=39828)     raise type(e)("%s\n"
# (RolloutWorker pid=39828) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) Second structure: type=int str=226
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# (RolloutWorker pid=39828) Entire first structure:
# (RolloutWorker pid=39828) (., {'prob': ., 'action_mask': .})
# (RolloutWorker pid=39828) Entire second structure:
# (RolloutWorker pid=39828) .
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
# (RolloutWorker pid=39828)   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
# (RolloutWorker pid=39828)   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
# (RolloutWorker pid=39828)   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
# (RolloutWorker pid=39828)   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
# (RolloutWorker pid=39828)   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
# (RolloutWorker pid=39828)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (RolloutWorker pid=39828)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 497, in __init__
# (RolloutWorker pid=39828)     check_env(self.env)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 88, in check_env
# (RolloutWorker pid=39828)     raise ValueError(
# (RolloutWorker pid=39828) ValueError: Traceback (most recent call last):
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 280, in assert_same_structure
# (RolloutWorker pid=39828)     _tree.assert_same_structure(a, b, check_types)
# (RolloutWorker pid=39828) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) Second structure: type=int str=226
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) During handling of the above exception, another exception occurred:
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
# (RolloutWorker pid=39828)     check_gym_environments(env)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
# (RolloutWorker pid=39828)     temp_sampled_reset_obs = convert_element_to_space_type(
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
# (RolloutWorker pid=39828)     return tree.map_structure(map_, element, sampled_element, check_types=False)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
# (RolloutWorker pid=39828)     assert_same_structure(structures[0], other, check_types=check_types)
# (RolloutWorker pid=39828)   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
# (RolloutWorker pid=39828)     raise type(e)("%s\n"
# (RolloutWorker pid=39828) ValueError: The two structures don't have the same nested structure.
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) Second structure: type=int str=226
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# (RolloutWorker pid=39828) Entire first structure:
# (RolloutWorker pid=39828) (., {'prob': ., 'action_mask': .})
# (RolloutWorker pid=39828) Entire second structure:
# (RolloutWorker pid=39828) .
# (RolloutWorker pid=39828)
# (RolloutWorker pid=39828) The above error has been found in your environment! We've added a module for checking your custom environments. It may cause your experiment to fail if your environment is not set up correctly. You can disable this behavior by setting `disable_env_checking=True` in your environment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env([env]).
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\algorithms\algorithm.py:524, in Algorithm.setup(self, config)
#     523 try:
# --> 524     self.workers = WorkerSet(
#     525         env_creator=self.env_creator,
#     526         validate_env=self.validate_env,
#     527         policy_class=self.get_default_policy_class(self.config),
#     528         trainer_config=self.config,
#     529         num_workers=self.config["num_workers"],
#     530         local_worker=True,
#     531         logdir=self.logdir,
#     532     )
#     533 # WorkerSet creation possibly fails, if some (remote) workers cannot
#     534 # be initialized properly (due to some errors in the RolloutWorker's
#     535 # constructor).
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\worker_set.py:139, in WorkerSet.__init__(self, env_creator, validate_env, policy_class, trainer_config, num_workers, local_worker, logdir, _setup)
#     138 self._remote_workers = []
# --> 139 self.add_workers(
#     140     num_workers,
#     141     validate=trainer_config.get("validate_workers_after_construction"),
#     142 )
#     144 # Create a local worker, if needed.
#     145 # If num_workers > 0 and we don't have an env on the local worker,
#     146 # get the observation- and action spaces for each policy from
#     147 # the first remote worker (which does have an env).
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\worker_set.py:490, in WorkerSet.add_workers(self, num_workers, validate)
#     489 if validate:
# --> 490     self.foreach_worker(lambda w: w.assert_healthy())
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\worker_set.py:620, in WorkerSet.foreach_worker(self, func)
#     619     local_result = [func(self.local_worker())]
# --> 620 remote_results = ray.get([w.apply.remote(func) for w in self.remote_workers()])
#     621 return local_result + remote_results
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\_private\client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\_private\worker.py:2291, in get(object_refs, timeout)
#    2290         else:
# -> 2291             raise value
#    2293 if is_individual_id:
#
# RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
#     check_gym_environments(env)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
#     temp_sampled_reset_obs = convert_element_to_space_type(
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
#     return tree.map_structure(map_, element, sampled_element, check_types=False)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
#     assert_same_structure(structures[0], other, check_types=check_types)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
#     raise type(e)("%s\n"
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# Entire first structure:
# (., {'prob': ., 'action_mask': .})
# Entire second structure:
# .
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
#   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 497, in __init__
#     check_env(self.env)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 88, in check_env
#     raise ValueError(
# ValueError: Traceback (most recent call last):
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 280, in assert_same_structure
#     _tree.assert_same_structure(a, b, check_types)
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=39828, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001D2C27C33A0>)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
#     check_gym_environments(env)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
#     temp_sampled_reset_obs = convert_element_to_space_type(
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
#     return tree.map_structure(map_, element, sampled_element, check_types=False)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
#     assert_same_structure(structures[0], other, check_types=check_types)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
#     raise type(e)("%s\n"
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# Entire first structure:
# (., {'prob': ., 'action_mask': .})
# Entire second structure:
# .
#
# The above error has been found in your environment! We've added a module for checking your custom environments. It may cause your experiment to fail if your environment is not set up correctly. You can disable this behavior by setting `disable_env_checking=True` in your environment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env([env]).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 12
#       1 from ray.rllib.algorithms.ppo import PPOConfig
#       3 config = (  # 1. Configure the algorithm,
#       4     PPOConfig()
#       5     .environment("Taxi-v3")
#    (...)
#       9     .evaluation(evaluation_num_workers=1)
#      10 )
# ---> 12 algo = config.build()  # 2. build the algorithm,
#      14 for _ in range(5):
#      15     print(algo.train())  # 3. train it,
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\algorithms\algorithm_config.py:311, in AlgorithmConfig.build(self, env, logger_creator)
#     308 if logger_creator is not None:
#     309     self.logger_creator = logger_creator
# --> 311 return self.algo_class(
#     312     config=self.to_dict(),
#     313     env=self.env,
#     314     logger_creator=self.logger_creator,
#     315 )
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\algorithms\algorithm.py:414, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     402 # Initialize common evaluation_metrics to nan, before they become
#     403 # available. We want to make sure the metrics are always present
#     404 # (although their values may be nan), so that Tune does not complain
#     405 # when we use these as stopping criteria.
#     406 self.evaluation_metrics = {
#     407     "evaluation": {
#     408         "episode_reward_max": np.nan,
#    (...)
#     411     }
#     412 }
# --> 414 super().__init__(config=config, logger_creator=logger_creator, **kwargs)
#     416 # Check, whether `training_iteration` is still a tune.Trainable property
#     417 # and has not been overridden by the user in the attempt to implement the
#     418 # algos logic (this should be done now inside `training_step`).
#     419 try:
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\tune\trainable\trainable.py:161, in Trainable.__init__(self, config, logger_creator, remote_checkpoint_dir, custom_syncer, sync_timeout)
#     159 start_time = time.time()
#     160 self._local_ip = ray.util.get_node_ip_address()
# --> 161 self.setup(copy.deepcopy(self.config))
#     162 setup_time = time.time() - start_time
#     163 if setup_time > SETUP_TIME_THRESHOLD:
#
# File c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\algorithms\algorithm.py:549, in Algorithm.setup(self, config)
#     536 except RayActorError as e:
#     537     # In case of an actor (remote worker) init failure, the remote worker
#     538     # may still exist and will be accessible, however, e.g. calling
#     539     # its `sample.remote()` would result in strange "property not found"
#     540     # errors.
#     541     if e.actor_init_failed:
#     542         # Raise the original error here that the RolloutWorker raised
#     543         # during its construction process. This is to enforce transparency
#    (...)
#     547         # - e.args[0].args[2]: The original Exception (e.g. a ValueError due
#     548         # to a config mismatch) thrown inside the actor.
# --> 549         raise e.args[0].args[2]
#     550     # In any other case, raise the RayActorError as-is.
#     551     else:
#     552         raise e
#
# ValueError: Traceback (most recent call last):
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 280, in assert_same_structure
#     _tree.assert_same_structure(a, b, check_types)
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 77, in check_env
#     check_gym_environments(env)
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\pre_checks\env.py", line 175, in check_gym_environments
#     temp_sampled_reset_obs = convert_element_to_space_type(
#   File "c:\Users\Robert\git\env8\lib\site-packages\ray\rllib\utils\spaces\space_utils.py", line 359, in convert_element_to_space_type
#     return tree.map_structure(map_, element, sampled_element, check_types=False)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 428, in map_structure
#     assert_same_structure(structures[0], other, check_types=check_types)
#   File "c:\Users\Robert\git\env8\lib\site-packages\tree\__init__.py", line 284, in assert_same_structure
#     raise type(e)("%s\n"
# ValueError: The two structures don't have the same nested structure.
#
# First structure: type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})
#
# Second structure: type=int str=226
#
# More specifically: Substructure "type=tuple str=(164, {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)})" is a sequence, while substructure "type=int str=226" is not
# Entire first structure:
# (., {'prob': ., 'action_mask': .})
# Entire second structure:
# .
#
# The above error has been found in your environment! We've added a module for checking your custom environments. It may cause your experiment to fail if your environment is not set up correctly. You can disable this behavior by setting `disable_env_checking=True` in your environment config dictionary. You can run the environment checking module standalone by calling ray.rllib.utils.check_env([env]).
